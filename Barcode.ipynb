# %%
pip install python-barcode
# Out:
# Collecting python-barcodeNote: you may need to restart the kernel to use updated packages.
#
#   Downloading python_barcode-0.15.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading python_barcode-0.15.1-py3-none-any.whl (212 kB)
#    ---------------------------------------- 0.0/213.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/213.0 kB ? eta -:--:--
#    --- ----------------------------------- 20.5/213.0 kB 217.9 kB/s eta 0:00:01
#    ----- --------------------------------- 30.7/213.0 kB 262.6 kB/s eta 0:00:01
#    ------- ------------------------------- 41.0/213.0 kB 219.4 kB/s eta 0:00:01
#    ----------- --------------------------- 61.4/213.0 kB 297.7 kB/s eta 0:00:01
#    -------------------- ----------------- 112.6/213.0 kB 437.6 kB/s eta 0:00:01
#    ------------------------- ------------ 143.4/213.0 kB 448.2 kB/s eta 0:00:01
#    ---------------------------------- --- 194.6/213.0 kB 537.4 kB/s eta 0:00:01
#    -------------------------------------- 213.0/213.0 kB 564.7 kB/s eta 0:00:00
# Installing collected packages: python-barcode
# Successfully installed python-barcode-0.15.1

# %%
import barcode
from barcode.writer import ImageWriter
from IPython.display import Image, display

user_data = input("Enter the data to encode in the barcode: ")
code = barcode.get('code128', user_data, writer = ImageWriter())

filename = code.save("clcoding_barcode")

display(Image(filename=filename))
# Out:
# Enter the data to encode in the barcode:  12345678
